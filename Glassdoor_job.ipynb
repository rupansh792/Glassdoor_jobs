# %%
import pandas as pd

# %%
df1= pd.read_csv(r"C:\Users\RUPANSH BHARDWAJ\Downloads\archive (6)\eda_data.csv")
df1
# Out:
#      Unnamed: 0                                          Job Title  \
# 0             0                                     Data Scientist
# 1             1                          Healthcare Data Scientist
# 2             2                                     Data Scientist
# 3             3                                     Data Scientist
# 4             4                                     Data Scientist
# ..          ...                                                ...
# 737         737           Sr Scientist, Immuno-Oncology - Oncology
# 738         738                               Senior Data Engineer
# 739         739  Project Scientist - Auton Lab, Robotics Institute
# 740         740                               Data Science Manager
# 741         741          Research Scientist – Security and Privacy
#
#                  Salary Estimate  \
# 0     $53K-$91K (Glassdoor est.)
# 1    $63K-$112K (Glassdoor est.)
# 2     $80K-$90K (Glassdoor est.)
# ...

# %%
df2= pd.read_csv(r"C:\Users\RUPANSH BHARDWAJ\Downloads\archive (6)\glassdoor_jobs.csv")
df2
# Out:
#      Unnamed: 0                                          Job Title  \
# 0             0                                     Data Scientist
# 1             1                          Healthcare Data Scientist
# 2             2                                     Data Scientist
# 3             3                                     Data Scientist
# 4             4                                     Data Scientist
# ..          ...                                                ...
# 951         951                               Senior Data Engineer
# 952         952  Project Scientist - Auton Lab, Robotics Institute
# 953         953                               Data Science Manager
# 954         954                                      Data Engineer
# 955         955          Research Scientist – Security and Privacy
#
#                  Salary Estimate  \
# 0     $53K-$91K (Glassdoor est.)
# 1    $63K-$112K (Glassdoor est.)
# 2     $80K-$90K (Glassdoor est.)
# ...

# %%
df3= pd.read_csv(r"C:\Users\RUPANSH BHARDWAJ\Downloads\archive (6)\salary_data_cleaned.csv")
df3
# Out:
#                                              Job Title  \
# 0                                       Data Scientist
# 1                            Healthcare Data Scientist
# 2                                       Data Scientist
# 3                                       Data Scientist
# 4                                       Data Scientist
# ..                                                 ...
# 737           Sr Scientist, Immuno-Oncology - Oncology
# 738                               Senior Data Engineer
# 739  Project Scientist - Auton Lab, Robotics Institute
# 740                               Data Science Manager
# 741          Research Scientist – Security and Privacy
#
#                  Salary Estimate  \
# 0     $53K-$91K (Glassdoor est.)
# 1    $63K-$112K (Glassdoor est.)
# 2     $80K-$90K (Glassdoor est.)
# 3     $56K-$97K (Glassdoor est.)
# 4    $86K-$143K (Glassdoor est.)
# ..                           ...
# 737  $58K-$111K (Glassdoor est.)
# ...

# %%
print(df1.columns)
print(df2.columns)
print(df3.columns)
# Out:
# Index(['Unnamed: 0', 'Job Title', 'Salary Estimate', 'Job Description',
#        'Rating', 'Company Name', 'Location', 'Headquarters', 'Size', 'Founded',
#        'Type of ownership', 'Industry', 'Sector', 'Revenue', 'Competitors',
#        'hourly', 'employer_provided', 'min_salary', 'max_salary', 'avg_salary',
#        'company_txt', 'job_state', 'same_state', 'age', 'python_yn', 'R_yn',
#        'spark', 'aws', 'excel', 'job_simp', 'seniority', 'desc_len',
#        'num_comp'],
#       dtype='object')
# Index(['Unnamed: 0', 'Job Title', 'Salary Estimate', 'Job Description',
#        'Rating', 'Company Name', 'Location', 'Headquarters', 'Size', 'Founded',
#        'Type of ownership', 'Industry', 'Sector', 'Revenue', 'Competitors'],
#       dtype='object')
# Index(['Job Title', 'Salary Estimate', 'Job Description', 'Rating',
#        'Company Name', 'Location', 'Headquarters', 'Size', 'Founded',
#        'Type of ownership', 'Industry', 'Sector', 'Revenue', 'Competitors',
# ...

# %%
df1.head()
# Out:
#    Unnamed: 0                  Job Title              Salary Estimate  \
# 0           0             Data Scientist   $53K-$91K (Glassdoor est.)
# 1           1  Healthcare Data Scientist  $63K-$112K (Glassdoor est.)
# 2           2             Data Scientist   $80K-$90K (Glassdoor est.)
# 3           3             Data Scientist   $56K-$97K (Glassdoor est.)
# 4           4             Data Scientist  $86K-$143K (Glassdoor est.)
#
#                                      Job Description  Rating  \
# 0  Data Scientist\nLocation: Albuquerque, NM\nEdu...     3.8
# 1  What You Will Do:\n\nI. General Summary\n\nThe...     3.4
# 2  KnowBe4, Inc. is a high growth information sec...     4.8
# 3  *Organization and Job ID**\nJob ID: 310709\n\n...     3.8
# 4  Data Scientist\nAffinity Solutions / Marketing...     2.9
#
#                                  Company Name         Location  \
# 0                      Tecolote Research\n3.8  Albuquerque, NM
# ...

# %%
df2.head()
# Out:
#    Unnamed: 0                  Job Title              Salary Estimate  \
# 0           0             Data Scientist   $53K-$91K (Glassdoor est.)
# 1           1  Healthcare Data Scientist  $63K-$112K (Glassdoor est.)
# 2           2             Data Scientist   $80K-$90K (Glassdoor est.)
# 3           3             Data Scientist   $56K-$97K (Glassdoor est.)
# 4           4             Data Scientist  $86K-$143K (Glassdoor est.)
#
#                                      Job Description  Rating  \
# 0  Data Scientist\nLocation: Albuquerque, NM\nEdu...     3.8
# 1  What You Will Do:\n\nI. General Summary\n\nThe...     3.4
# 2  KnowBe4, Inc. is a high growth information sec...     4.8
# 3  *Organization and Job ID**\nJob ID: 310709\n\n...     3.8
# 4  Data Scientist\nAffinity Solutions / Marketing...     2.9
#
#                                  Company Name         Location  \
# 0                      Tecolote Research\n3.8  Albuquerque, NM
# ...

# %%
df3.head()
# Out:
#                    Job Title              Salary Estimate  \
# 0             Data Scientist   $53K-$91K (Glassdoor est.)
# 1  Healthcare Data Scientist  $63K-$112K (Glassdoor est.)
# 2             Data Scientist   $80K-$90K (Glassdoor est.)
# 3             Data Scientist   $56K-$97K (Glassdoor est.)
# 4             Data Scientist  $86K-$143K (Glassdoor est.)
#
#                                      Job Description  Rating  \
# 0  Data Scientist\nLocation: Albuquerque, NM\nEdu...     3.8
# 1  What You Will Do:\n\nI. General Summary\n\nThe...     3.4
# 2  KnowBe4, Inc. is a high growth information sec...     4.8
# 3  *Organization and Job ID**\nJob ID: 310709\n\n...     3.8
# 4  Data Scientist\nAffinity Solutions / Marketing...     2.9
#
#                                  Company Name         Location  \
# 0                      Tecolote Research\n3.8  Albuquerque, NM
# 1  University of Maryland Medical System\n3.4    Linthicum, MD
# ...

# %%
df1.tail()
# Out:
#      Unnamed: 0                                          Job Title  \
# 737         737           Sr Scientist, Immuno-Oncology - Oncology
# 738         738                               Senior Data Engineer
# 739         739  Project Scientist - Auton Lab, Robotics Institute
# 740         740                               Data Science Manager
# 741         741          Research Scientist – Security and Privacy
#
#                  Salary Estimate  \
# 737  $58K-$111K (Glassdoor est.)
# 738  $72K-$133K (Glassdoor est.)
# 739   $56K-$91K (Glassdoor est.)
# 740  $95K-$160K (Glassdoor est.)
# 741  $61K-$126K (Glassdoor est.)
#
#                                        Job Description  Rating  \
# 737  Site Name: USA - Massachusetts - Cambridge\nPo...     3.9
# 738  THE CHALLENGE\nEventbrite has a world-class da...     4.4
# 739  The Auton Lab at Carnegie Mellon University is...     2.6
# 740  Data Science ManagerResponsibilities:\n\nOvers...     3.2
# ...

# %%
df1.tail()
# Out:
#      Unnamed: 0                                          Job Title  \
# 737         737           Sr Scientist, Immuno-Oncology - Oncology
# 738         738                               Senior Data Engineer
# 739         739  Project Scientist - Auton Lab, Robotics Institute
# 740         740                               Data Science Manager
# 741         741          Research Scientist – Security and Privacy
#
#                  Salary Estimate  \
# 737  $58K-$111K (Glassdoor est.)
# 738  $72K-$133K (Glassdoor est.)
# 739   $56K-$91K (Glassdoor est.)
# 740  $95K-$160K (Glassdoor est.)
# 741  $61K-$126K (Glassdoor est.)
#
#                                        Job Description  Rating  \
# 737  Site Name: USA - Massachusetts - Cambridge\nPo...     3.9
# 738  THE CHALLENGE\nEventbrite has a world-class da...     4.4
# 739  The Auton Lab at Carnegie Mellon University is...     2.6
# 740  Data Science ManagerResponsibilities:\n\nOvers...     3.2
# ...

# %%
df2.tail()
# Out:
#      Unnamed: 0                                          Job Title  \
# 951         951                               Senior Data Engineer
# 952         952  Project Scientist - Auton Lab, Robotics Institute
# 953         953                               Data Science Manager
# 954         954                                      Data Engineer
# 955         955          Research Scientist – Security and Privacy
#
#                  Salary Estimate  \
# 951  $72K-$133K (Glassdoor est.)
# 952   $56K-$91K (Glassdoor est.)
# 953  $95K-$160K (Glassdoor est.)
# 954                           -1
# 955  $61K-$126K (Glassdoor est.)
#
#                                        Job Description  Rating  \
# 951  THE CHALLENGE\nEventbrite has a world-class da...     4.4
# 952  The Auton Lab at Carnegie Mellon University is...     2.6
# 953  Data Science ManagerResponsibilities:\n\nOvers...     3.2
# 954  Loading...\n\nTitle: Data Engineer\n\nLocation...     4.8
# ...

# %%
df3.tail()
# Out:
#                                              Job Title  \
# 737           Sr Scientist, Immuno-Oncology - Oncology
# 738                               Senior Data Engineer
# 739  Project Scientist - Auton Lab, Robotics Institute
# 740                               Data Science Manager
# 741          Research Scientist – Security and Privacy
#
#                  Salary Estimate  \
# 737  $58K-$111K (Glassdoor est.)
# 738  $72K-$133K (Glassdoor est.)
# 739   $56K-$91K (Glassdoor est.)
# 740  $95K-$160K (Glassdoor est.)
# 741  $61K-$126K (Glassdoor est.)
#
#                                        Job Description  Rating  \
# 737  Site Name: USA - Massachusetts - Cambridge\nPo...     3.9
# 738  THE CHALLENGE\nEventbrite has a world-class da...     4.4
# 739  The Auton Lab at Carnegie Mellon University is...     2.6
# 740  Data Science ManagerResponsibilities:\n\nOvers...     3.2
# 741  Returning Candidate? Log back in to the Career...     3.6
#
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 742 entries, 0 to 741
# Data columns (total 33 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         742 non-null    int64
#  1   Job Title          742 non-null    object
#  2   Salary Estimate    742 non-null    object
#  3   Job Description    742 non-null    object
#  4   Rating             742 non-null    float64
#  5   Company Name       742 non-null    object
#  6   Location           742 non-null    object
#  7   Headquarters       742 non-null    object
#  8   Size               742 non-null    object
#  9   Founded            742 non-null    int64
#  10  Type of ownership  742 non-null    object
#  11  Industry           742 non-null    object
#  12  Sector             742 non-null    object
#  13  Revenue            742 non-null    object
#  14  Competitors        742 non-null    object
#  15  hourly             742 non-null    int64
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 956 entries, 0 to 955
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         956 non-null    int64
#  1   Job Title          956 non-null    object
#  2   Salary Estimate    956 non-null    object
#  3   Job Description    956 non-null    object
#  4   Rating             956 non-null    float64
#  5   Company Name       956 non-null    object
#  6   Location           956 non-null    object
#  7   Headquarters       956 non-null    object
#  8   Size               956 non-null    object
#  9   Founded            956 non-null    int64
#  10  Type of ownership  956 non-null    object
#  11  Industry           956 non-null    object
#  12  Sector             956 non-null    object
#  13  Revenue            956 non-null    object
#  14  Competitors        956 non-null    object
# dtypes: float64(1), int64(2), object(12)
# ...

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 742 entries, 0 to 741
# Data columns (total 28 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Job Title          742 non-null    object
#  1   Salary Estimate    742 non-null    object
#  2   Job Description    742 non-null    object
#  3   Rating             742 non-null    float64
#  4   Company Name       742 non-null    object
#  5   Location           742 non-null    object
#  6   Headquarters       742 non-null    object
#  7   Size               742 non-null    object
#  8   Founded            742 non-null    int64
#  9   Type of ownership  742 non-null    object
#  10  Industry           742 non-null    object
#  11  Sector             742 non-null    object
#  12  Revenue            742 non-null    object
#  13  Competitors        742 non-null    object
#  14  hourly             742 non-null    int64
#  15  employer_provided  742 non-null    int64
# ...

# %%
df1.describe()
# Out:
#        Unnamed: 0      Rating      Founded      hourly  employer_provided  \
# count  742.000000  742.000000   742.000000  742.000000         742.000000
# mean   370.500000    3.618868  1837.154987    0.032345           0.022911
# std    214.341239    0.801210   497.183763    0.177034           0.149721
# min      0.000000   -1.000000    -1.000000    0.000000           0.000000
# 25%    185.250000    3.300000  1939.000000    0.000000           0.000000
# 50%    370.500000    3.700000  1988.000000    0.000000           0.000000
# 75%    555.750000    4.000000  2007.000000    0.000000           0.000000
# max    741.000000    5.000000  2019.000000    1.000000           1.000000
#
#        min_salary  max_salary  avg_salary  same_state         age   python_yn  \
# count  742.000000  742.000000  742.000000  742.000000  742.000000  742.000000
# mean    74.719677  128.149596  100.626011    0.557951   46.591644    0.528302
# ...

# %%
df2.describe()
# Out:
#        Unnamed: 0      Rating      Founded
# count  956.000000  956.000000   956.000000
# mean   477.500000    3.601255  1774.605649
# std    276.117729    1.067619   598.942517
# min      0.000000   -1.000000    -1.000000
# 25%    238.750000    3.300000  1937.000000
# 50%    477.500000    3.800000  1992.000000
# 75%    716.250000    4.200000  2008.000000
# max    955.000000    5.000000  2019.000000

# %%
df3.describe()
# Out:
#            Rating      Founded      hourly  employer_provided  min_salary  \
# count  742.000000   742.000000  742.000000         742.000000  742.000000
# mean     3.618868  1837.154987    0.032345           0.022911   74.068733
# std      0.801210   497.183763    0.177034           0.149721   31.869282
# min     -1.000000    -1.000000    0.000000           0.000000   10.000000
# 25%      3.300000  1939.000000    0.000000           0.000000   52.000000
# 50%      3.700000  1988.000000    0.000000           0.000000   69.500000
# 75%      4.000000  2007.000000    0.000000           0.000000   91.000000
# max      5.000000  2019.000000    1.000000           1.000000  202.000000
#
#        max_salary  avg_salary  same_state         age   python_yn        R_yn  \
# count  742.000000  742.000000  742.000000  742.000000  742.000000  742.000000
# mean   127.183288  100.626011    0.557951   46.591644    0.528302    0.002695
# ...

# %%
df1.isnull()
# Out:
#      Unnamed: 0  Job Title  Salary Estimate  Job Description  Rating  \
# 0         False      False            False            False   False
# 1         False      False            False            False   False
# 2         False      False            False            False   False
# 3         False      False            False            False   False
# 4         False      False            False            False   False
# ..          ...        ...              ...              ...     ...
# 737       False      False            False            False   False
# 738       False      False            False            False   False
# 739       False      False            False            False   False
# 740       False      False            False            False   False
# 741       False      False            False            False   False
#
#      Company Name  Location  Headquarters   Size  Founded  ...    age  \
# ...

# %%
df2.isnull()
# Out:
#      Unnamed: 0  Job Title  Salary Estimate  Job Description  Rating  \
# 0         False      False            False            False   False
# 1         False      False            False            False   False
# 2         False      False            False            False   False
# 3         False      False            False            False   False
# 4         False      False            False            False   False
# ..          ...        ...              ...              ...     ...
# 951       False      False            False            False   False
# 952       False      False            False            False   False
# 953       False      False            False            False   False
# 954       False      False            False            False   False
# 955       False      False            False            False   False
#
#      Company Name  Location  Headquarters   Size  Founded  Type of ownership  \
# ...

# %%
df3.isnull()
# Out:
#      Job Title  Salary Estimate  Job Description  Rating  Company Name  \
# 0        False            False            False   False         False
# 1        False            False            False   False         False
# 2        False            False            False   False         False
# 3        False            False            False   False         False
# 4        False            False            False   False         False
# ..         ...              ...              ...     ...           ...
# 737      False            False            False   False         False
# 738      False            False            False   False         False
# 739      False            False            False   False         False
# 740      False            False            False   False         False
# 741      False            False            False   False         False
#
#      Location  Headquarters   Size  Founded  Type of ownership  ...  \
# ...

# %%
print(df1.columns)
print(df2.columns)
print(df3.columns)
# Out:
# Index(['Unnamed: 0', 'Job Title', 'Salary Estimate', 'Job Description',
#        'Rating', 'Company Name', 'Location', 'Headquarters', 'Size', 'Founded',
#        'Type of ownership', 'Industry', 'Sector', 'Revenue', 'Competitors',
#        'hourly', 'employer_provided', 'min_salary', 'max_salary', 'avg_salary',
#        'company_txt', 'job_state', 'same_state', 'age', 'python_yn', 'R_yn',
#        'spark', 'aws', 'excel', 'job_simp', 'seniority', 'desc_len',
#        'num_comp'],
#       dtype='object')
# Index(['Unnamed: 0', 'Job Title', 'Salary Estimate', 'Job Description',
#        'Rating', 'Company Name', 'Location', 'Headquarters', 'Size', 'Founded',
#        'Type of ownership', 'Industry', 'Sector', 'Revenue', 'Competitors'],
#       dtype='object')
# Index(['Job Title', 'Salary Estimate', 'Job Description', 'Rating',
#        'Company Name', 'Location', 'Headquarters', 'Size', 'Founded',
#        'Type of ownership', 'Industry', 'Sector', 'Revenue', 'Competitors',
# ...

# %%
df1.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 737    False
# 738    False
# 739    False
# 740    False
# 741    False
# Length: 742, dtype: bool

# %%
df1.shape
# Out:
# (742, 33)

# %%
df2.shape
# Out:
# (956, 15)

# %%
df3.shape
# Out:
# (742, 28)

# %%
print(df1.idxmax(), Industry.max())
print(df2.idxmax(), Industry.max())
print(df3.idxmax(), Industry.max())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 print(df1.idxmax(), Industry.max())
#       2 print(df2.idxmax(), Industry.max())
#       3 print(df3.idxmax(), Industry.max())
#
# NameError: name 'Industry' is not defined

# %%
df1["Industry"].value_counts()
# Out:
# Industry
# Biotech & Pharmaceuticals                   112
# Insurance Carriers                           63
# Computer Hardware & Software                 59
# IT Services                                  50
# Health Care Services & Hospitals             49
# Enterprise Software & Network Solutions      42
# Internet                                     29
# Consulting                                   29
# Aerospace & Defense                          25
# Advertising & Marketing                      25
# Consumer Products Manufacturing              20
# Research & Development                       19
# Colleges & Universities                      16
# Energy                                       14
# Banks & Credit Unions                        12
# Federal Agencies                             11
# -1                                           10
# Staffing & Outsourcing                       10
# Travel Agencies                               8
# ...

# %%
df2["Industry"].value_counts()
# Out:
# Industry
# Biotech & Pharmaceuticals                   148
# IT Services                                  77
# Computer Hardware & Software                 70
# Insurance Carriers                           65
# Enterprise Software & Network Solutions      56
#                                            ...
# Farm Support Services                         1
# Transportation Equipment Manufacturing        1
# Motion Picture Production & Distribution      1
# Other Retail Stores                           1
# Beauty & Personal Accessories Stores          1
# Name: count, Length: 63, dtype: int64

# %%
df3["Industry"].value_counts()
# Out:
# Industry
# Biotech & Pharmaceuticals                   112
# Insurance Carriers                           63
# Computer Hardware & Software                 59
# IT Services                                  50
# Health Care Services & Hospitals             49
# Enterprise Software & Network Solutions      42
# Internet                                     29
# Consulting                                   29
# Aerospace & Defense                          25
# Advertising & Marketing                      25
# Consumer Products Manufacturing              20
# Research & Development                       19
# Colleges & Universities                      16
# Energy                                       14
# Banks & Credit Unions                        12
# Federal Agencies                             11
# -1                                           10
# Staffing & Outsourcing                       10
# Travel Agencies                               8
# ...

# %%
df3["Location"].value_counts()
# Out:
# Location
# New York, NY                         55
# San Francisco, CA                    49
# Cambridge, MA                        47
# Chicago, IL                          32
# Boston, MA                           23
#                                      ..
# Santa Fe Springs, Los Angeles, CA     1
# Kansas City, MO                       1
# Columbia, SC                          1
# Red Bank, NJ                          1
# Olympia, WA                           1
# Name: count, Length: 200, dtype: int64

# %%
df2["Location"].value_counts()
# Out:
# Location
# New York, NY         78
# San Francisco, CA    71
# Cambridge, MA        59
# Chicago, IL          37
# Boston, MA           24
#                      ..
# Red Bank, NJ          1
# San Ramon, CA         1
# Woodinville, WA       1
# Burlington, MA        1
# Michigan              1
# Name: count, Length: 237, dtype: int64

# %%
df1["Location"].value_counts()
# Out:
# Location
# New York, NY                         55
# San Francisco, CA                    49
# Cambridge, MA                        47
# Chicago, IL                          32
# Boston, MA                           23
#                                      ..
# Santa Fe Springs, Los Angeles, CA     1
# Kansas City, MO                       1
# Columbia, SC                          1
# Red Bank, NJ                          1
# Olympia, WA                           1
# Name: count, Length: 200, dtype: int64

# %%
# 6.What are the top 10 companies hiring?

# %%
df1["Company Name"].value_counts().head(10)
# Out:
# Company Name
# MassMutual\n3.6                          14
# Reynolds American\n3.1                   14
# Takeda Pharmaceuticals\n3.7              14
# Software Engineering Institute\n2.6      11
# PNNL\n3.8                                10
# Liberty Mutual Insurance\n3.3            10
# AstraZeneca\n3.9                          9
# MITRE\n3.2                                8
# Numeric, LLC\n3.2                         7
# Advanced BioScience Laboratories\n2.7     7
# Name: count, dtype: int64

# %%
df2["Company Name"].value_counts().head(10)
# Out:
# Company Name
# Novartis\n3.8                                           14
# MassMutual\n3.6                                         14
# Takeda Pharmaceuticals\n3.7                             14
# Reynolds American\n3.1                                  14
# Software Engineering Institute\n2.6                     13
# The Church of Jesus Christ of Latter-day Saints\n4.2    13
# Liberty Mutual Insurance\n3.3                           10
# PNNL\n3.8                                               10
# AstraZeneca\n3.9                                         9
# MITRE\n3.2                                               8
# Name: count, dtype: int64

# %%
df3["Company Name"].value_counts().head(10)
# Out:
# Company Name
# MassMutual\n3.6                          14
# Reynolds American\n3.1                   14
# Takeda Pharmaceuticals\n3.7              14
# Software Engineering Institute\n2.6      11
# PNNL\n3.8                                10
# Liberty Mutual Insurance\n3.3            10
# AstraZeneca\n3.9                          9
# MITRE\n3.2                                8
# Numeric, LLC\n3.2                         7
# Advanced BioScience Laboratories\n2.7     7
# Name: count, dtype: int64

# %%
#7.	What is the average company rating?

# %%
df3["Rating"].value_counts().mean()
# Out:
# np.float64(23.93548387096774)

# %%
df2["Rating"].value_counts().mean()
# Out:
# np.float64(29.875)

# %%
df1["Rating"].value_counts().mean()
# Out:
# np.float64(23.93548387096774)

# %%
#8.	What is the average salary across all jobs?

# %%
df1["avg_salary"].mean()
# Out:
# np.float64(100.62601078167116)

# %%
df3["avg_salary"].mean()
# Out:
# np.float64(100.62601078167116)

# %%
# 9.Which company has the highest average rating?

# %%
df1.groupby("Company Name")["Rating"].mean().sort_values(ascending=False).head(1)
# Out:
# Company Name
# BPA Services\n5.0    5.0
# Name: Rating, dtype: float64

# %%
df2.groupby("Company Name")["Rating"].mean().sort_values(ascending=False).head(1)
# Out:
# Company Name
# Brightside\n5.0    5.0
# Name: Rating, dtype: float64

# %%
df3.groupby("Company Name")["Rating"].mean().sort_values(ascending=False).head(1)
# Out:
# Company Name
# BPA Services\n5.0    5.0
# Name: Rating, dtype: float64

# %%
# 10. Which job title appears most frequently?

# %%
# 13
df1.groupby('Location')['avg_salary'].mean().sort_values(ascending=False).head(5)
# Out:
# Location
# Bellevue, WA         184.5000
# Lake Forest, IL      179.5000
# Mountain View, CA    177.1875
# Novato, CA           168.0000
# Burbank, CA          164.0000
# Name: avg_salary, dtype: float64

# %%
# 14 
df3.groupby("python_yn")["avg_salary"].mean()
# Out:
# python_yn
# 0     87.155714
# 1    112.653061
# Name: avg_salary, dtype: float64

# %%
# 15.	Compare salaries for companies with ratings above 4.0 and below 4.0.

# %%
df3["rating_group"]=df3["Rating"].apply(lambda x: "above 4" if x >4 else "4 or below")
df3.groupby("rating_group")["avg_salary"].mean()
# Out:
# rating_group
# 4 or below     99.233333
# above 4       105.241279
# Name: avg_salary, dtype: float64

# %%
df3["rating_group"].head(10)
# Out:
# 0    4 or below
# 1    4 or below
# 2       above 4
# 3    4 or below
# 4    4 or below
# 5    4 or below
# 6       above 4
# 7    4 or below
# 8    4 or below
# 9       above 4
# Name: rating_group, dtype: object

# %%
#16
df3.groupby("Company Name")['max_salary'].max().sort_values(ascending=False).head(5)
# Out:
# Company Name
# Liberty Mutual Insurance\n3.3    306
# Sage Intacct\n4.7                289
# Gallup\n4.2                      275
# Grand Rounds\n4.2                272
# CA-One Tech Cloud                250
# Name: max_salary, dtype: int64

# %%
df3["salary_range"] = df3["max_salary"] - df3["min_salary"]

# %%
df3.nlargest(10,'salary_range')
# Out:
#                                              Job Title  \
# 76         Customer Data Scientist/Sales Engineer (Bay
# 146             Customer Data Scientist/Sales Engineer
# 91                                    Sr. Scientist II
# 429               Principal Machine Learning Scientist
# 133                       Scientist 2, QC Viral Vector
# 619                        Senior Quantitative Analyst
# 637  Research Scientist / Principal Research Scient...
# 354          Director II, Data Science - GRM Actuarial
# 528          Director II, Data Science - GRM Actuarial
# 708          Director II, Data Science - GRM Actuarial
#
#                   Salary Estimate  \
# 76    $79K-$222K (Glassdoor est.)
# 146   $71K-$204K (Glassdoor est.)
# 91   $117K-$231K (Glassdoor est.)
# 429  $176K-$289K (Glassdoor est.)
# 133  $113K-$223K (Glassdoor est.)
# 619  $118K-$228K (Glassdoor est.)
# 637  $115K-$220K (Glassdoor est.)
# 354  $202K-$306K (Glassdoor est.)
# 528  $202K-$306K (Glassdoor est.)
# ...

# %%
# 18.	Find the top 10 highest-paying companies
df3.groupby("Company Name")["avg_salary"].max().sort_values(ascending=False).head(10)
# Out:
# Company Name
# Liberty Mutual Insurance\n3.3    254.0
# Gallup\n4.2                      237.5
# Sage Intacct\n4.7                232.5
# CA-One Tech Cloud                225.0
# Grand Rounds\n4.2                221.5
# Credit Sesame\n4.1               205.0
# The Climate Corporation\n3.2     194.0
# Visa Inc.\n3.7                   184.5
# Tapjoy\n3.9                      181.0
# Zest AI\n3.9                     180.0
# Name: avg_salary, dtype: float64

# %%
df1['python_yn'].value_counts()
# Out:
# python_yn
# 1    392
# 0    350
# Name: count, dtype: int64

# %%
df3['python_yn'].value_counts()
# Out:
# python_yn
# 1    392
# 0    350
# Name: count, dtype: int64

# %%
df3['R_yn'].value_counts()
# Out:
# R_yn
# 0    740
# 1      2
# Name: count, dtype: int64

# %%
df1['R_yn'].value_counts()
# Out:
# R_yn
# 0    740
# 1      2
# Name: count, dtype: int64

# %%
df3['aws'].value_counts()
# Out:
# aws
# 0    566
# 1    176
# Name: count, dtype: int64

# %%
df1['aws'].value_counts()
# Out:
# aws
# 0    566
# 1    176
# Name: count, dtype: int64

# %%
df3['spark'].sum()
# Out:
# np.int64(167)

# %%
df1['spark'].sum()
# Out:
# np.int64(167)

# %%
df1['excel'].sum()
# Out:
# np.int64(388)

# %%
df3['excel'].sum()
# Out:
# np.int64(388)

# %%
skills=["python_yn","excel","spark","aws","R_yn"]

# %%
df1[skills].sum().sort_values(ascending=False)
# Out:
# python_yn    392
# excel        388
# aws          176
# spark        167
# R_yn           2
# dtype: int64

# %%
df1[df1["python_yn"]==1]["Job Title"].value_counts()
# Out:
# Job Title
# Data Scientist                                 109
# Data Engineer                                   39
# Senior Data Scientist                           29
# Senior Data Analyst                             11
# Senior Data Engineer                             9
#                                               ...
# Associate Data Scientist/Computer Scientist      1
# Data Scientist, Rice University                  1
# Insurance Data Scientist                         1
# Customer Data Scientist/Sales Engineer (Bay      1
# Machine Learning Engineer (NLP)                  1
# Name: count, Length: 114, dtype: int64

# %%
df3.groupby("Industry")["python_yn"].mean().sort_values(ascending=False).head(1)
# Out:
# Industry
# Consumer Product Rental    1.0
# Name: python_yn, dtype: float64

# %%
# 27.	Compare the average salary of jobs requiring AWS versus those that don't.
df1.groupby("avg_salary")["aws"].mean()
# Out:
# avg_salary
# 13.5     0.0
# 15.5     0.0
# 20.0     0.0
# 20.5     0.0
# 21.5     1.0
#         ...
# 221.5    0.0
# 225.0    1.0
# 232.5    0.0
# 237.5    0.0
# 254.0    0.0
# Name: aws, Length: 225, dtype: float64

# %%
# 28.	Compare the average salary of jobs requiring Spark versus those that don't .
df1.groupby("avg_salary")["spark"].mean()
# Out:
# avg_salary
# 13.5     0.0
# 15.5     0.0
# 20.0     0.0
# 20.5     0.0
# 21.5     0.0
#         ...
# 221.5    0.0
# 225.0    0.0
# 232.5    0.0
# 237.5    0.0
# 254.0    0.0
# Name: spark, Length: 225, dtype: float64

# %%
#   29.	Which companies have the highest average ratings?
df1.groupby('Company Name')['Rating'].mean().sort_values(ascending=False).head(1)
# Out:
# Company Name
# BPA Services\n5.0    5.0
# Name: Rating, dtype: float64

# %%
# 30.Do larger companies pay more than smaller companies?
df1.groupby('Size')['avg_salary'].mean().sort_values()
# Out:
# Size
# 501 to 1000 employees       90.753731
# 1001 to 5000 employees      92.916667
# 5001 to 10000 employees     96.552632
# 201 to 500 employees       100.247863
# 1 to 50 employees          102.306452
# 51 to 200 employees        111.351064
# 10000+ employees           112.230769
# -1                         117.500000
# Unknown                    128.111111
# Name: avg_salary, dtype: float64

# %%
# 31.	Which company size hires the most data scientists?
df1[df1['Job Title']=='Data Scientist']['Company Name'].value_counts().idxmax()
# Out:
# 'Oversight Systems\n4.7'

# %%
# 32 Which ownership type offers the highest salaries? 
df1.groupby('Type of ownership')['avg_salary'].mean()
# Out:
# Type of ownership
# -1                                117.500000
# College / University              107.615385
# Company - Private                 101.776829
# Company - Public                  110.893782
# Government                         84.300000
# Hospital                           54.000000
# Nonprofit Organization             68.281818
# Other Organization                 77.500000
# School / School District           77.750000
# Subsidiary or Business Segment    110.573529
# Unknown                            39.500000
# Name: avg_salary, dtype: float64

# %%
#33.	Which sector pays the highest salaries?
df1.groupby('Sector')['avg_salary'].mean().idxmax()
# Out:
# 'Media'

# %%
# 34.Which revenue category has the highest average salary?
df1.groupby('Revenue')['avg_salary'].mean().idxmax()
# Out:
# '$5 to $10 million (USD)'

# %%
# 35. Do older companies pay better than newer companies?

# %%
# 36.	Which state has the most job postings?
df1['job_state'].value_counts().idxmax()
# Out:
# 'CA'

# %%
# 37.	Which state has the highest average salary?
df1.groupby('job_state')['avg_salary'].mean().sort_values(ascending=False).head(1)
# Out:
# job_state
# CA    123.513158
# Name: avg_salary, dtype: float64

# %%
# 38.	Which city has the most job opportunities?
df1['Location'].value_counts().idxmax()
# Out:
# 'New York, NY'

# %%
# 39.	Compare salaries for jobs where headquarters and job location are in the same state versus different states (same_state).

# %%
#  40.	Which locations have the highest company ratings?
df1.groupby('Location')['Rating'].mean().sort_values(ascending=False).head(1)
# Out:
# Location
# Ann Arbor, MI    5.0
# Name: Rating, dtype: float64

# %%
# 41.	Create a bar chart showing the top 10 hiring companies.
df1["Company Name"].value_counts().head(10).plot(kind="bar")
# Out:
# <Axes: xlabel='Company Name'>

# %%
# 42.	Create a bar chart of average salary by industry.
df1.groupby('Industry')['avg_salary'].mean()
df1["Industry"].value_counts().head(15).plot(kind="bar")
# Out:
# <Axes: xlabel='Industry'>

# %%
# 43.	Plot a histogram of average salaries.
df1["avg_salary"].value_counts().head(15).plot(kind="hist")
# Out:
# <Axes: ylabel='Frequency'>

# %%
#44.	Plot a histogram of company ratings.
df1["Rating"].value_counts().plot(kind="hist")
# Out:
# <Axes: ylabel='Frequency'>

# %%
# 45.	Create a scatter plot of company rating vs average salary.
df1.plot.scatter(x="Rating",y="avg_salary")
# Out:
# <Axes: xlabel='Rating', ylabel='avg_salary'>

# %%
# 46.	Create a scatter plot of company age vs average salary
df1.plot.scatter(x="age",y="avg_salary")
# Out:
# <Axes: xlabel='age', ylabel='avg_salary'>

# %%
# 47.	Create a box plot of salaries by job title.
df1.boxplot(column="avg_salary",by="Job Title")
# Out:
# <Axes: title={'center': 'avg_salary'}, xlabel='Job Title'>

# %%
# 48.	Create a box plot of salaries by company size.
df1.boxplot(column="avg_salary",by="Size")
# Out:
# <Axes: title={'center': 'avg_salary'}, xlabel='Size'>

# %%
# 49.	Create a pie chart showing the distribution of industries
df1["Industry"].value_counts().plot(kind="pie")
# Out:
# <Axes: ylabel='count'>

# %%
# 50.	Create a line chart showing average salary by company age (after grouping by age).
df1.groupby("age")["avg_salary"].mean().plot(kind="line")
# Out:
# <Axes: xlabel='age'>

# %%
# 51.	Create a new column called salary_range.
df1["salary_range"]=df1["max_salary"]-df1["min_salary"]
df1.nlargest(10,"salary_range")
# Out:
#      Unnamed: 0                                          Job Title  \
# 76           76        Customer Data Scientist/Sales Engineer (Bay
# 146         146             Customer Data Scientist/Sales Engineer
# 91           91                                   Sr. Scientist II
# 429         429               Principal Machine Learning Scientist
# 133         133                       Scientist 2, QC Viral Vector
# 619         619                        Senior Quantitative Analyst
# 637         637  Research Scientist / Principal Research Scient...
# 354         354          Director II, Data Science - GRM Actuarial
# 528         528          Director II, Data Science - GRM Actuarial
# 708         708          Director II, Data Science - GRM Actuarial
#
#                   Salary Estimate  \
# 76    $79K-$222K (Glassdoor est.)
# 146   $71K-$204K (Glassdoor est.)
# 91   $117K-$231K (Glassdoor est.)
# 429  $176K-$289K (Glassdoor est.)
# 133  $113K-$223K (Glassdoor est.)
# ...

# %%
# 52.	Categorize salaries into:
#•	Low
#•	Medium
#•	High

df3["rating_group"]=df3["Rating"].apply(lambda x: "above 4" if x >4 else "4 or below")
df3.groupby("rating_group")["avg_salary"].mean()
# Out:
# rating_group
# 4 or below     99.233333
# above 4       105.241279
# Name: avg_salary, dtype: float64

# %%
df3["salary_range"] = df3["avg_salary"].apply(lambda x: "Low" if x < 60000 else ("Medium" if x < 120000 else "High"))
df3.groupby("salary_range")["avg_salary"].mean()
# Out:
# salary_range
# Low    100.626011
# Name: avg_salary, dtype: float64

# %%
df3["salary_range"] = df3["avg_salary"].apply(lambda x: "Low" if x < 60 else ("Medium" if x < 120 else "High"))
df3.groupby("salary_range")["avg_salary"].mean()
# Out:
# salary_range
# High      148.592417
# Low        42.869318
# Medium     89.252822
# Name: avg_salary, dtype: float64

# %%
# 53.	Create a column indicating whether the salary is above the dataset average.
average_salary = df1["avg_salary"].mean()
df1["above_average"]=df1["avg_salary"].apply(lambda x :"yes" if x> average_salary else "no")

# %%
df1["above_average"].value_counts()
# Out:
# above_average
# no     405
# yes    337
# Name: count, dtype: int64

# %%
# 54.	Count the number of technical skills listed for each job.

# %%
# 55.	Find jobs requiring at least 3 technical skills.
df3[(df3['python_yn'] + df3['aws'] + df3['excel']) >= 3]
# Out:
#                            Job Title               Salary Estimate  \
# 5                     Data Scientist   $71K-$119K (Glassdoor est.)
# 7                     Data Scientist   $86K-$142K (Glassdoor est.)
# 13                      Data Analyst    $46K-$85K (Glassdoor est.)
# 17           Customer Data Scientist  $118K-$189K (Glassdoor est.)
# 22     Data Scientist - Quantitative   $86K-$139K (Glassdoor est.)
# ..                               ...                           ...
# 684                   Data Scientist   $77K-$132K (Glassdoor est.)
# 688                    Data Engineer   $79K-$147K (Glassdoor est.)
# 709        Machine Learning Engineer   $91K-$159K (Glassdoor est.)
# 732  Machine Learning Engineer (NLP)   $80K-$142K (Glassdoor est.)
# 735                    Data Engineer   $62K-$113K (Glassdoor est.)
#
#                                        Job Description  Rating  \
# 5    CyrusOne is seeking a talented Data Scientist ...     3.4
# ...

# %%
#  56. Is company rating correlated with salary?
df3["Rating"].corr(df3["avg_salary"])
# Out:
# np.float64(0.013491724007337814)

# %%
# 57.	Is company age correlated with salary?
df3["age"].corr(df3["avg_salary"])
# Out:
# np.float64(0.019655073606614577)

# %%
# 58.	Which numeric variables are strongly correlated?
df3.corr(numeric_only=True)
# Out:
#                      Rating   Founded    hourly  employer_provided  \
# Rating             1.000000  0.332927 -0.019531          -0.468234
# Founded            0.332927  1.000000  0.049313          -0.312761
# hourly            -0.019531  0.049313  1.000000           0.124748
# employer_provided -0.468234 -0.312761  0.124748           1.000000
# min_salary        -0.007825 -0.038513 -0.309674           0.164277
# max_salary         0.027668  0.001069 -0.379516           0.014773
# avg_salary         0.013492 -0.015149 -0.356082           0.076287
# same_state         0.085033  0.171512 -0.067351          -0.081349
# age                0.021655  0.134682  0.007626          -0.109288
# python_yn          0.144665  0.103183 -0.193487          -0.107924
# R_yn              -0.004472  0.016045 -0.009505          -0.007961
# spark              0.156982  0.066978 -0.098530          -0.082524
# aws                0.117049 -0.011123 -0.030315          -0.000685
# ...

# %%
#  59.	Create a correlation heatmap.
#NOT DONE

# %%
#  60.	Which variables have the strongest relationship with average salary?
df1.corr(numeric_only=True)["avg_salary"].sort_values(ascending=False)
# Out:
# avg_salary           1.000000
# max_salary           0.986862
# min_salary           0.967765
# salary_range         0.760802
# python_yn            0.327796
# spark                0.176559
# aws                  0.171379
# num_comp             0.093813
# desc_len             0.078808
# employer_provided    0.076287
# age                  0.019655
# Rating               0.013492
# Founded             -0.015149
# same_state          -0.034641
# R_yn                -0.040000
# Unnamed: 0          -0.041765
# excel               -0.057252
# hourly              -0.356082
# Name: avg_salary, dtype: float64

# %%
#  61.If you were looking for the highest-paying jobs , which industries should you target ?
df3.groupby('Job Title')['avg_salary'].mean()
# Out:
# Job Title
# Ag Data Scientist                                      80.5
# Analytics - Business Assurance Data Analyst            43.0
# Analytics Consultant                                   66.5
# Analytics Manager                                      87.5
# Analytics Manager - Data Mart                          64.0
#                                                       ...
# System and Data Analyst                                59.0
# Systems Engineer II - Data Analyst                     62.5
# Technology-Minded, Data Professional Opportunities     70.5
# VP, Data Science                                      124.5
# Web Data Analyst                                      106.0
# Name: avg_salary, Length: 264, dtype: float64

# %%
# 62.	Does knowing Python actually lead to higher salaries? Quantify the difference.
df3.groupby('python_yn')['avg_salary'].mean()
# Out:
# python_yn
# 0     87.155714
# 1    112.653061
# Name: avg_salary, dtype: float64

# %%
# 63.	Which combination of skills (Python, AWS, Spark, R, Excel) results in the highest average salary?
skills = ['python_yn', 'aws', 'spark', 'R_yn', 'excel']
df3.groupby(skills)['avg_salary'].mean().sort_values(ascending=False)
# Out:
# python_yn  aws  spark  R_yn  excel
# 0          1    1      0     0        130.857143
# 1          1    1      0     0        124.363636
#                 0      0     0        116.233333
#            0    0      0     0        114.565476
# 0          1    1      0     1        114.333333
# 1          1    0      0     1        112.293103
#                 1      0     1        112.045455
#            0    1      0     1        111.843750
#                              0        111.784091
# 0          1    0      0     1        110.095238
# 1          0    0      0     1        108.119048
# 0          0    1      0     1         95.388889
#                 0      0     0         87.319853
#                              1         81.692053
#            1    0      0     0         79.500000
# 1          0    0      1     1         70.750000
# 0          0    1      0     0         56.500000
# Name: avg_salary, dtype: float64

# %%
#  64.	Which states have the highest demand for data scientists?
df3['job_state'].value_counts()
# Out:
# job_state
# CA             151
# MA             103
# NY              72
# VA              41
# IL              40
# MD              35
# PA              33
# TX              28
# WA              21
# NC              21
# NJ              17
# FL              16
# OH              14
# TN              13
# DC              11
# CO              11
# WI              10
# IN              10
# UT              10
# AZ               9
# MO               9
# AL               8
# GA               6
# KY               6
# DE               6
# MI               6
# CT               5
# IA               5
# LA               4
# OR               4
# NE               4
# NM               3
# KS               3
# ID               2
# MN               2
# Los Angeles      1
# RI               1
# SC               1
# Name: count, dtype: int64

# %%
# 65.	Are startups or large enterprises paying better salaries?
df3.groupby('Size')['avg_salary'].mean().sort_values(ascending=False)
# Out:
# Size
# Unknown                    128.111111
# -1                         117.500000
# 10000+ employees           112.230769
# 51 to 200 employees        111.351064
# 1 to 50 employees          102.306452
# 201 to 500 employees       100.247863
# 5001 to 10000 employees     96.552632
# 1001 to 5000 employees      92.916667
# 501 to 1000 employees       90.753731
# Name: avg_salary, dtype: float64

# %%
# 66.	Do highly rated companies offer better salaries?
df3.groupby('Rating')['avg_salary'].mean().sort_values(ascending=False)
# Out:
# Rating
# -1.0    136.181818
#  5.0    134.700000
#  2.5    120.000000
#  4.5    117.714286
#  4.1    116.368421
#  3.9    113.071429
#  2.6    109.083333
#  4.4    108.606061
#  3.2    105.500000
#  4.0    105.340426
#  3.5    104.897959
#  3.7    104.131148
#  4.7    103.983871
#  4.3    102.468750
#  3.3    101.858974
#  4.2    100.442308
#  2.2     97.750000
#  4.6     97.250000
#  3.8     96.811475
#  2.1     95.900000
#  3.4     93.011364
#  1.9     87.500000
#  3.1     86.580000
#  3.0     85.588235
#  3.6     85.467391
#  2.8     83.928571
#  2.7     83.250000
#  2.3     81.500000
#  2.9     81.138889
#  4.8     80.277778
#  2.4     60.214286
# Name: avg_salary, dtype: float64

# %%
#  67.	Which companies offer both high salaries and high ratings?
df3[(df3['avg_salary'] > df3['avg_salary'].mean()) & (df3['Rating'] > df3['Rating'].mean())][['Company Name', 'avg_salary', 'Rating']].sort_values('avg_salary', ascending=False)
# Out:
#                  Company Name  avg_salary  Rating
# 103               Gallup\n4.2       237.5     4.2
# 429         Sage Intacct\n4.7       232.5     4.7
# 613         Grand Rounds\n4.2       221.5     4.2
# 330        Credit Sesame\n4.1       205.0     4.1
# 195        Credit Sesame\n4.1       205.0     4.1
# ..                        ...         ...     ...
# 556           Eventbrite\n4.4       102.5     4.4
# 738           Eventbrite\n4.4       102.5     4.4
# 251             Genworth\n3.7       102.0     3.7
# 16   Blueprint Medicines\n3.9       102.0     3.9
# 424     Royce Geospatial\n5.0       101.0     5.0
#
# [201 rows x 3 columns]

# %%
# 68.	Which skills should a new graduate learn to maximize salary?
skills = ['python_yn', 'aws', 'spark', 'R_yn', 'excel']
df3[skills].apply(lambda col: df3.groupby(col)['avg_salary'].mean().max()).sort_values(ascending=False)
# Out:
# spark        113.347305
# python_yn    112.653061
# aws          112.559659
# excel        102.953390
# R_yn         100.706757
# dtype: float64

# %%
# 69.	Which job titles are most common, and which pay the best?
df3.groupby('Job Title')['avg_salary'].agg(['count', 'mean']).sort_values('count', ascending=False)
# Out:
#                                       count        mean
# Job Title
# Data Scientist                          131  106.179389
# Data Engineer                            53   91.660377
# Senior Data Scientist                    34  134.867647
# Data Analyst                             15   66.300000
# Senior Data Engineer                     14  121.928571
# ...                                     ...         ...
# Jr. Data Scientist                        1  106.500000
# Junior Data Analyst                       1   50.000000
# Lead Health Data Analyst - Front End      1  100.000000
# Machine Learning Engineer (NLP)           1  111.000000
# Web Data Analyst                          1  106.000000
#
# [264 rows x 2 columns]

# %%
# 70.	If you were advising a student entering data science, what are the top three insights from this dataset?
